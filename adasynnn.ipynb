# %%
import pandas as pd
final_data = pd.read_csv('Final_data.csv')

# %%
X = final_data.drop('loan_status', axis = 1)
y = final_data['loan_status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from imblearn.over_sampling import ADASYN

# %%
from imblearn.over_sampling import SMOTEN, ADASYN
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import time

adasyn = ADASYN(
    sampling_strategy='auto',
    random_state=42,
    n_neighbors=5)

start_time1 = time.time()

X_resampled, y_resampled = adasyn.fit_resample(X_train, y_train)

end_time1 = time.time()
execution_time1 = end_time1 - start_time1
print("Waktu fitting:", execution_time1, "detik")
# Out:
# Waktu fitting: 9.34623384475708 detik

# %%
from xgboost import XGBClassifier
from tqdm import tqdm
from sklearn.metrics import classification_report

xgb = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    learning_rate=0.1,
    max_depth=3,
    n_estimators=100,
    verbose=True
)

# Fitting (training) the model with a progress bar
progress_bar = tqdm(total=xgb.n_estimators)

def update_progress_bar(*args, **kwargs):
    progress_bar.update(1)

# Specify eval_set for evaluation during training
eval_set = [(X_test, y_test)]

start_time2 = time.time()
# Fit the model with eval_set
xgb.fit(X_resampled, y_resampled, eval_set=eval_set)


end_time2 = time.time()
execution_time2 = end_time2 - start_time2
print("Waktu fitting:", execution_time2, "detik")
# Make predictions
y_pred = xgb.predict(X_test)
y_pred_resampled = xgb.predict(X_resampled)

# Evaluate the model
target_names = ['bad', 'poor', 'good']
print(classification_report(y_resampled, y_pred_resampled, target_names=target_names))
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [21:03:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-mlogloss:0.97762
# [1]	validation_0-mlogloss:0.87649
# [2]	validation_0-mlogloss:0.79095
# [3]	validation_0-mlogloss:0.71516
# [4]	validation_0-mlogloss:0.64989
# [5]	validation_0-mlogloss:0.59444
# [6]	validation_0-mlogloss:0.54466
# [7]	validation_0-mlogloss:0.50103
# [8]	validation_0-mlogloss:0.46280
# [9]	validation_0-mlogloss:0.42758
# [10]	validation_0-mlogloss:0.39738
# [11]	validation_0-mlogloss:0.36917
# [12]	validation_0-mlogloss:0.34418
# [13]	validation_0-mlogloss:0.32115
# [14]	validation_0-mlogloss:0.29998
# [15]	validation_0-mlogloss:0.28156
# [16]	validation_0-mlogloss:0.26479
# [17]	validation_0-mlogloss:0.24928
# [18]	validation_0-mlogloss:0.23597
# [19]	validation_0-mlogloss:0.22315
# [20]	validation_0-mlogloss:0.21167
# [21]	validation_0-mlogloss:0.20070
# [22]	validation_0-mlogloss:0.19044
# [23]	validation_0-mlogloss:0.18192
# [24]	validation_0-mlogloss:0.17279
# [25]	validation_0-mlogloss:0.16501
# [26]	validation_0-mlogloss:0.15612
# [27]	validation_0-mlogloss:0.14892
# [28]	validation_0-mlogloss:0.14184
# [29]	validation_0-mlogloss:0.13584
# [30]	validation_0-mlogloss:0.13023
# [31]	validation_0-mlogloss:0.12415
# [32]	validation_0-mlogloss:0.11946
# [33]	validation_0-mlogloss:0.11514
# [34]	validation_0-mlogloss:0.11092
# [35]	validation_0-mlogloss:0.10731
# [36]	validation_0-mlogloss:0.10392
# [37]	validation_0-mlogloss:0.09942
# [38]	validation_0-mlogloss:0.09649
# [39]	validation_0-mlogloss:0.09294
# [40]	validation_0-mlogloss:0.09046
# [41]	validation_0-mlogloss:0.08731
# [42]	validation_0-mlogloss:0.08329
# [43]	validation_0-mlogloss:0.08118
# [44]	validation_0-mlogloss:0.07752
# [45]	validation_0-mlogloss:0.07567
# [46]	validation_0-mlogloss:0.07411
# [47]	validation_0-mlogloss:0.07100
# [48]	validation_0-mlogloss:0.06949
# [49]	validation_0-mlogloss:0.06672
# [50]	validation_0-mlogloss:0.06467
# [51]	validation_0-mlogloss:0.06336
# [52]	validation_0-mlogloss:0.06156
# [53]	validation_0-mlogloss:0.05956
# [54]	validation_0-mlogloss:0.05777
# [55]	validation_0-mlogloss:0.05566
# [56]	validation_0-mlogloss:0.05341
# [57]	validation_0-mlogloss:0.05250
# [58]	validation_0-mlogloss:0.05057
# [59]	validation_0-mlogloss:0.04906
# [60]	validation_0-mlogloss:0.04768
# [61]	validation_0-mlogloss:0.04580
# [62]	validation_0-mlogloss:0.04443
# [63]	validation_0-mlogloss:0.04374
# [64]	validation_0-mlogloss:0.04202
# [65]	validation_0-mlogloss:0.04084
# [66]	validation_0-mlogloss:0.03946
# [67]	validation_0-mlogloss:0.03859
# [68]	validation_0-mlogloss:0.03747
# [69]	validation_0-mlogloss:0.03586
# [70]	validation_0-mlogloss:0.03485
# [71]	validation_0-mlogloss:0.03406
# [72]	validation_0-mlogloss:0.03289
# [73]	validation_0-mlogloss:0.03227
# [74]	validation_0-mlogloss:0.03112
# [75]	validation_0-mlogloss:0.03061
# [76]	validation_0-mlogloss:0.02965
# [77]	validation_0-mlogloss:0.02920
# [78]	validation_0-mlogloss:0.02845
# [79]	validation_0-mlogloss:0.02799
# [80]	validation_0-mlogloss:0.02742
# [81]	validation_0-mlogloss:0.02673
# [82]	validation_0-mlogloss:0.02634
# [83]	validation_0-mlogloss:0.02579
# [84]	validation_0-mlogloss:0.02535
# [85]	validation_0-mlogloss:0.02493
# [86]	validation_0-mlogloss:0.02419
# [87]	validation_0-mlogloss:0.02388
# [88]	validation_0-mlogloss:0.02321
# [89]	validation_0-mlogloss:0.02305
# [90]	validation_0-mlogloss:0.02252
# [91]	validation_0-mlogloss:0.02209
# [92]	validation_0-mlogloss:0.02184
# [93]	validation_0-mlogloss:0.02140
# [94]	validation_0-mlogloss:0.02102
# [95]	validation_0-mlogloss:0.02079
# [96]	validation_0-mlogloss:0.02050
# [97]	validation_0-mlogloss:0.02015
# [98]	validation_0-mlogloss:0.01997
# [99]	validation_0-mlogloss:0.01982
# Waktu fitting: 53.16583776473999 detik
#               precision    recall  f1-score   support
#
#          bad       1.00      0.99      1.00    102534
#         poor       1.00      1.00      1.00    104721
#         good       1.00      1.00      1.00    104802
#
#     accuracy                           1.00    312057
#    macro avg       1.00      1.00      1.00    312057
# weighted avg       1.00      1.00      1.00    312057
#
#               precision    recall  f1-score   support
#
#          bad       1.00      0.99      0.99      6597
#         poor       0.98      1.00      0.99      2187
#         good       1.00      1.00      1.00     26234
#
#     accuracy                           1.00     35018
#    macro avg       0.99      1.00      0.99     35018
# weighted avg       1.00      1.00      1.00     35018
